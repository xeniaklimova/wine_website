# %%
import pandas as pd
df = pd.read_csv('wine_url.csv')
df.dropna(subset=['price'], inplace=True)

# %%
df.head()
print(df['province'].isna().sum())
# Out:
# 0

# %%
# Out:
# Fetched for Banrock Station 2006 Chardonnay (South Eastern Australia): https://www.wineenthusiast.com/wp-content/assets/reviews/label-images/wine/wine/77731_53BBE_2001_050108.jpg
# Fetched for Cellier des Dauphins 2015 Réserve Rosé (Côtes du Rhône): https://images.vivino.com/thumbs/hEgKAJjUQLePbwzlgvNg-Q_pb_x600.png
# Fetched for Esperanza 2013 Estate Grown & Bottled Verdejo-Viura (Rueda): https://cdn.ct-static.com/labels/6c82a891-83aa-41c7-8c4e-5b59f4fb15f5.jpg
# Fetched for Midnight 2010 Nebula Cabernet Sauvignon (Paso Robles): https://static.wineaccess.com/images/products/Bottle_Red_proper_size.png
# Fetched for Harrington 2006 Wiley Vineyard Pinot Noir (Anderson Valley): https://www.princeofpinot.com/media/images/07_19/07_19-16.jpg
# ...

# %%
# Out:
# Number of rows with 'img_url' == None: 1
#    Unnamed: 0    country                                        description  \
# 0       77718  Australia  Possibly a little sweet, this is a soft, easyg...
# 1       67681     France  A soft, almost off dry wine that is full in th...
# 2       69877      Spain  Generic white-fruit aromas of peach and apple ...
# 3       46544         US  This is the winery's best Nebula in years. Whi...
# 4         186         US  This is a very rich Pinot whose primary virtue...
#
#               designation  points  price         province  \
# 0                     NaN      83    5.0  Australia Other
# 1                 Réserve      85   12.0     Rhône Valley
# 2  Estate Grown & Bottled      86    9.0   Northern Spain
# 3                  Nebula      87   29.0       California
# 4          Wiley Vineyard      88   40.0       California
#
#                   region_1       region_2        taster_name  \
# ...

# %%
# Out:
# Number of rows with 'img_url' == None: 76
